# %% [markdown]
# ## Exploratory Data Analysis-(EDA)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# !pip install openpyxl
# Out:
# Requirement already satisfied: openpyxl in C:\Users\javee\anaconda3\Lib\site-packages (3.1.5)
# Requirement already satisfied: et-xmlfile in C:\Users\javee\anaconda3\Lib\site-packages (from openpyxl) (2.0.0)

# %%
# Import pandas and ensure openpyxl is available
import pandas as pd

# Note: Make sure openpyxl is installed by running:
# conda install openpyxl  OR  pip install openpyxl

# Read Excel File
df = pd.read_excel('PJMW_MW_Hourly.xlsx')

# %%
# First 5 columns
df.head()
# Out:
#              Datetime  PJMW_MW
# 0 2002-12-31 01:00:00     5077
# 1 2002-12-31 02:00:00     4939
# 2 2002-12-31 03:00:00     4885
# 3 2002-12-31 04:00:00     4857
# 4 2002-12-31 05:00:00     4930

# %%
# Last 5 columns
df.tail()
# Out:
#                   Datetime  PJMW_MW
# 143201 2018-01-01 20:00:00     8401
# 143202 2018-01-01 21:00:00     8373
# 143203 2018-01-01 22:00:00     8238
# 143204 2018-01-01 23:00:00     7958
# 143205 2018-01-02 00:00:00     7691

# %%
# Dataset columns
df.columns
# Out:
# Index(['Datetime', 'PJMW_MW'], dtype='str')

# %%
# Dataset shape
print(df.shape)
# Out:
# (143206, 2)

# %%
# data type 
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 143206 entries, 0 to 143205
# Data columns (total 2 columns):
#  #   Column    Non-Null Count   Dtype
# ---  ------    --------------   -----
#  0   Datetime  143206 non-null  datetime64[us]
#  1   PJMW_MW   143206 non-null  int64
# dtypes: datetime64[us](1), int64(1)
# memory usage: 2.2 MB

# %%
# Statistical Summary
df.describe()
# Out:
#                          Datetime        PJMW_MW
# count                      143206  143206.000000
# mean   2010-06-02 03:39:50.656815    5602.375089
# min           2002-04-01 01:00:00     487.000000
# 25%           2006-05-02 03:15:00    4907.000000
# 50%           2010-06-02 04:30:00    5530.000000
# 75%           2014-07-03 06:45:00    6252.000000
# max           2018-08-03 00:00:00    9594.000000
# std                           NaN     979.142872

# %%
# Missing values
df.isnull().sum()
# Out:
# Datetime    0
# PJMW_MW     0
# dtype: int64

# %%
df['Datetime'] = pd.to_datetime(df['Datetime'])  # convert date time
df = df.sort_values('Datetime')                  # sort chronologically(oldest to newest)
df.set_index('Datetime', inplace=True)           # make datetime the index
df.head()
# Out:
#                      PJMW_MW
# Datetime
# 2002-04-01 01:00:00     4374
# 2002-04-01 02:00:00     4306
# 2002-04-01 03:00:00     4322
# 2002-04-01 04:00:00     4359
# 2002-04-01 05:00:00     4436

# %% [markdown]
# ### Overall Time Series Visualization

# %%
# Energy consumption over time

plt.figure(figsize=(18,6))

plt.plot(df['PJMW_MW'])
plt.title('Hourly Energy Consumption')
plt.xlabel('Date')
plt.ylabel('MegaWatts')

plt.show()

# %% [markdown]
# #### Distribution of energy consumption

# %%
# Histplot

plt.figure(figsize=(10,5))

sns.histplot(df['PJMW_MW'],
            bins=50,
            kde=True
            )
plt.title('Distribution of Energy Consumption')

plt.show()

# %% [markdown]
# #### Boxplot for Outlier Detection

# %%
# Boxplot

plt.figure(figsize=(10,6))

sns.boxplot(y=df['PJMW_MW'])
plt.title('Outlier Detection')

plt.show()

# %% [raw]
# For this PJMW electricity demand forecasting dataset, do NOT remove the outliers by default.
#
# The reason is that these "outliers" are very likely real electricity demand events, not data entry errors.

# %% [markdown]
# ### Feature Engineering

# %%
# Feature Extraction

df['hour'] = df.index.hour
df['dayofweek'] = df.index.dayofweek
df['month'] = df.index.month
df['quarter'] = df.index.quarter
df['year'] = df.index.year
df['dayofyear'] = df.index.dayofyear
df['day_name'] = df.index.day_name()

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# DatetimeIndex: 143206 entries, 2002-04-01 01:00:00 to 2018-08-03 00:00:00
# Data columns (total 8 columns):
#  #   Column     Non-Null Count   Dtype
# ---  ------     --------------   -----
#  0   PJMW_MW    143206 non-null  int64
#  1   hour       143206 non-null  int32
#  2   dayofweek  143206 non-null  int32
#  3   month      143206 non-null  int32
#  4   quarter    143206 non-null  int32
#  5   year       143206 non-null  int32
#  6   dayofyear  143206 non-null  int32
#  7   day_name   143206 non-null  str
# dtypes: int32(6), int64(1), str(1)
# memory usage: 7.5 MB

# %%
df.head()
# Out:
#                      PJMW_MW  hour  dayofweek  month  quarter  year  \
# Datetime
# 2002-04-01 01:00:00     4374     1          0      4        2  2002
# 2002-04-01 02:00:00     4306     2          0      4        2  2002
# 2002-04-01 03:00:00     4322     3          0      4        2  2002
# 2002-04-01 04:00:00     4359     4          0      4        2  2002
# 2002-04-01 05:00:00     4436     5          0      4        2  2002
#
#                      dayofyear day_name
# Datetime
# 2002-04-01 01:00:00         91   Monday
# 2002-04-01 02:00:00         91   Monday
# 2002-04-01 03:00:00         91   Monday
# 2002-04-01 04:00:00         91   Monday
# 2002-04-01 05:00:00         91   Monday

# %% [markdown]
# ### Hourly Analysis

# %%
hourly_avg = df.groupby('hour')['PJMW_MW'].mean()

plt.figure(figsize=(12,6))

hourly_avg.plot()
plt.title('Average power demand by hour')
plt.xlabel('Hour')
plt.ylabel('Average MW')

plt.show()

# %% [markdown]
# ### Week Trend Analysis

# %%
plt.figure(figsize=(10,5))

sns.boxplot(
    x='day_name',
    y='PJMW_MW',
    data=df
)

plt.title('Power Demand by Day of Week')

plt.show()

# %% [markdown]
# ### Monthly Trend Analysis

# %%
monthly_avg = df.groupby('month')['PJMW_MW'].mean()

plt.figure(figsize=(10,5))

monthly_avg.plot(marker='o')

plt.title("Monthly Average Demand")

plt.xlabel("Month")
plt.ylabel("MW")

plt.show()

# %% [markdown]
# ### Yearly trend analysis

# %%
yearly_avg = df.groupby('year')['PJMW_MW'].mean()

plt.figure(figsize=(10,5))

yearly_avg.plot(marker='o')
plt.title("Yearly Average Demand")
plt.ylabel("MW")

plt.show()

# %% [markdown]
# ### Seasonal Analysis

# %%
summer = df[df['month'].isin([6,7,8])]
winter = df[df['month'].isin([12,1,2])]

print("Summer Avg Demand:",summer['PJMW_MW'].mean())

print("Winter Avg Demand:",winter['PJMW_MW'].mean())
# Out:
# Summer Avg Demand: 5734.206129041014
# Winter Avg Demand: 6268.813850815178

# %%
plt.figure(figsize=(12,5))

summer.groupby('hour')['PJMW_MW'].mean().plot(label='Summer')

winter.groupby('hour')['PJMW_MW'].mean().plot(label='Winter')

plt.legend()
plt.title('Summer vs Winter Consumption')
plt.show()

# %% [markdown]
# ### Rolling Average

# %%
df['rolling_30day'] = df['PJMW_MW'].rolling(24*30).mean()

plt.figure(figsize=(16,6))

plt.plot(df['PJMW_MW'],
         label='Original'
        )
plt.plot(df['rolling_30day'],
         label='30-Day MA'
        )
plt.legend()
plt.show()

# %% [markdown]
# ### Correlation Analysis

# %%
cols = ['PJMW_MW', 'hour', 'dayofweek', 'month', 'quarter', 'year', 'dayofyear']

plt.figure(figsize=(8,6))

sns.heatmap(df[cols].corr(),
           annot=True,
           cmap='coolwarm')
plt.title('Correlation Heatmap')

plt.show()

# %% [markdown]
# ### LAG Features

# %%
df['lag24'] = df['PJMW_MW'].shift(24)           # lag24 (same hour previous day)
df['lag48'] = df['PJMW_MW'].shift(48)           # lag48 (same hour two days ago)
df['lag168'] = df['PJMW_MW'].shift(168)         # lag168 (same hour previous week)

df[['PJMW_MW',
    'lag24',
    'lag48',
    'lag168']].head()
# Out:
#                      PJMW_MW  lag24  lag48  lag168
# Datetime
# 2002-04-01 01:00:00     4374    NaN    NaN     NaN
# 2002-04-01 02:00:00     4306    NaN    NaN     NaN
# 2002-04-01 03:00:00     4322    NaN    NaN     NaN
# 2002-04-01 04:00:00     4359    NaN    NaN     NaN
# 2002-04-01 05:00:00     4436    NaN    NaN     NaN

# %% [markdown]
# #### Rolling features

# %%
df['rolling24_mean'] = df['PJMW_MW'].rolling(24).mean()
df['rolling168_mean'] = df['PJMW_MW'].rolling(168).mean()

# %%
df.drop('day_name', axis=1, inplace=True) # day_name is useful for EDA and visualization only
df.dropna(inplace=True)

# %%
df.head()
# Out:
#                      PJMW_MW  hour  dayofweek  month  quarter  year  \
# Datetime
# 2002-05-01 01:00:00     4503     1          2      5        2  2002
# 2002-05-01 02:00:00     4418     2          2      5        2  2002
# 2002-05-01 03:00:00     4310     3          2      5        2  2002
# 2002-05-01 04:00:00     4282     4          2      5        2  2002
# 2002-05-01 05:00:00     4431     5          2      5        2  2002
#
#                      dayofyear  rolling_30day   lag24   lag48  lag168  \
# Datetime
# 2002-05-01 01:00:00        121    5169.756944  4755.0  4075.0  4827.0
# 2002-05-01 02:00:00        121    5169.818056  4599.0  3990.0  4738.0
# 2002-05-01 03:00:00        121    5169.823611  4528.0  3999.0  4711.0
# 2002-05-01 04:00:00        121    5169.768056  4555.0  4016.0  4743.0
# 2002-05-01 05:00:00        121    5169.868056  4654.0  4109.0  4912.0
#
#                      rolling24_mean  rolling168_mean
# Datetime
# 2002-05-01 01:00:00     5206.750000      5032.523810
# 2002-05-01 02:00:00     5199.208333      5030.619048
# 2002-05-01 03:00:00     5190.125000      5028.232143
# 2002-05-01 04:00:00     5178.750000      5025.488095
# 2002-05-01 05:00:00     5169.458333      5022.625000

# %% [markdown]
# #### Checking duplicate timestamps

# %%
# print("Duplicate timestamps:", df.index.duplicated().sum())

# %%
# print(df.index[df.index.duplicated()])

# %%
# df = df[~df.index.duplicated(keep='first')]

# %%
df = df.groupby(df.index).mean()

# %%
# print(df.index.freq)
# print(df.index.inferred_freq)
# print(df.index.duplicated().sum())

# %% [raw]
# # Set the frequency of the DatetimeIndex
# df = df.asfreq('h')
#
# # Duplicate timestamps
# print(df.index.duplicated().sum())
#
# # Missing timestamps
# print(df.index.to_series().diff().value_counts().head())
#
# # Check frequency
# print(df.index.freq)
# print(df.index.inferred_freq)
#
# # Check if any NaNs were introduced
# print(df.isna().sum().sum())

# %%
# print(df[df.isna().any(axis=1)].head())

# %%
# print(df.isna().sum())

# %%
df = df.dropna()

# %% [markdown]
# ## Model Building

# %% [markdown]
# #### Train Test Split

# %%
from sklearn.model_selection import train_test_split

# Features and Target
X = df.drop('PJMW_MW', axis=1)
y = df['PJMW_MW']

# Chronological Split
X_train, X_test, y_train, y_test = train_test_split(
    X,
    y,
    test_size=0.2,
    shuffle=False
)

# %%
X_train.shape, X_test.shape, y_train.shape, y_test.shape
# Out:
# ((113986, 12), (28497, 12), (113986,), (28497,))

# %% [markdown]
# #### Scaling

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()

X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# %% [markdown]
# ### Model-1 Linear Regression

# %%
from sklearn.linear_model import LinearRegression

lr_model = LinearRegression()

lr_model.fit(X_train_scaled, y_train)
# Out:
# LinearRegression()

# %% [markdown]
# #### Prediction

# %%
lr_pred = lr_model.predict(X_test_scaled)

# %% [markdown]
# #### Evaluation

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

# %%
lr_mae = mean_absolute_error(y_test, lr_pred)

lr_rmse = np.sqrt(mean_squared_error(y_test, lr_pred))

lr_r2 =  r2_score(y_test, lr_pred)

print("Linear Regression")
print("MAE:", lr_mae)
print("RMSE:", lr_rmse)
print("R2:", lr_r2)
# Out:
# Linear Regression
# MAE: 289.70405837629266
# RMSE: 371.3581341152772
# R2: 0.8606246957600348

# %% [markdown]
# #### Visualization Plot

# %%
plt.figure(figsize=(15,5))
plt.plot(y_test.index, y_test, label='Actual')
plt.plot(y_test.index, lr_pred, label='Predicted')
plt.title('Linear Regression')
plt.legend()
plt.show()

# %% [markdown]
# ### Model-2 Random Forest

# %%
from sklearn.ensemble import RandomForestRegressor

rf_model = RandomForestRegressor(
    n_estimators=100,
    max_depth=12,
    min_samples_leaf=5,
    n_jobs=1,
    random_state=42
)

rf_model.fit(X_train_scaled, y_train)
# Out:
# RandomForestRegressor(max_depth=12, min_samples_leaf=5, n_jobs=1,
#                       random_state=42)

# %% [markdown]
# #### Prediction

# %%
rf_pred = rf_model.predict(X_test_scaled)

# %% [markdown]
# #### Evaluation

# %%
rf_mae = mean_absolute_error(y_test, rf_pred)

rf_rmse = np.sqrt(mean_squared_error(y_test, rf_pred))

rf_r2 =  r2_score(y_test, rf_pred)

print("Random Forest")
print("MAE:", rf_mae)
print("RMSE:", rf_rmse)
print("R2:", rf_r2)
# Out:
# Random Forest
# MAE: 235.23771329411434
# RMSE: 313.7057054361809
# R2: 0.9005408413398776

# %% [markdown]
# #### Visualization Plot

# %%
plt.figure(figsize=(15,5))
plt.plot(y_test.index, y_test, label='Actual')
plt.plot(y_test.index, rf_pred, label='Predicted')
plt.title('Random Forest Forecast')
plt.legend()
plt.show()

# %% [markdown]
# ### Model-3 XGBoost

# %%
from xgboost import XGBRegressor

xgb_model = XGBRegressor(
    n_estimators=500,
    learning_rate=0.05,
    max_depth=6,
    random_state=42
)

xgb_model.fit(X_train_scaled, y_train)
# Out:
# XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=None, device=None, early_stopping_rounds=None,
#              enable_categorical=False, eval_metric=None, feature_types=None,
#              feature_weights=None, gamma=None, grow_policy=None,
#              importance_type=None, interaction_constraints=None,
#              learning_rate=0.05, max_bin=None, max_cat_threshold=None,
#              max_cat_to_onehot=None, max_delta_step=None, max_depth=6,
#              max_leaves=None, min_child_weight=None, missing=nan,
#              monotone_constraints=None, multi_strategy=None, n_estimators=500,
#              n_jobs=None, num_parallel_tree=None, ...)

# %% [markdown]
# #### Prediction

# %%
xgb_pred = xgb_model.predict(X_test_scaled)

# %% [markdown]
# #### Evaluation

# %%
xgb_mae = mean_absolute_error(y_test, xgb_pred)

xgb_rmse = np.sqrt(mean_squared_error(y_test, xgb_pred))

xgb_r2 =  r2_score(y_test, xgb_pred)

print("XGBoost")
print("MAE:", xgb_mae)
print("RMSE:", xgb_rmse)
print("R2:", xgb_r2)
# Out:
# XGBoost
# MAE: 209.60276886156603
# RMSE: 276.88490023351676
# R2: 0.9225184159142699

# %% [markdown]
# #### Visualization Plot

# %%
plt.figure(figsize=(15,5))
plt.plot(y_test.index, y_test, label='Actual')
plt.plot(y_test.index, xgb_pred, label='Predicted')
plt.title('XGBoost Forecast')
plt.legend()
plt.show()

# %% [markdown]
# #### Model-4 Holt-Winters

# %% [raw]
# Holt-Winters works only on the target series.

# %% [markdown]
# #### Train-Test-Split

# %%
train_hw, test_hw = train_test_split(
    df['PJMW_MW'],
    test_size=0.2,
    random_state=42
)

# %%
from statsmodels.tsa.holtwinters import ExponentialSmoothing

# %% [markdown]
# #### Model Building

# %%
hw_model = ExponentialSmoothing(
    train_hw,
    trend='add',
    seasonal='add',
    seasonal_periods=24
)

hw_fit = hw_model.fit()
# Out:
# C:\Users\javee\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# C:\Users\javee\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it is not monotonic and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)

# %% [markdown]
# #### Prediction

# %%
hw_pred = hw_fit.forecast(len(test_hw))
# Out:
# C:\Users\javee\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:837: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   return get_prediction_index(
# C:\Users\javee\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:837: FutureWarning: No supported index is available. In the next version, calling this method in a model without a supported index will result in an exception.
#   return get_prediction_index(

# %% [markdown]
# #### Evaluation

# %%
hw_mae = mean_absolute_error(test_hw, hw_pred)

hw_rmse = np.sqrt(mean_squared_error(test_hw, hw_pred))

hw_r2 =  r2_score(test_hw, hw_pred)

print("Holt-Winters")
print("MAE:", hw_mae)
print("RMSE:", hw_rmse)
print("R2:", hw_r2)
# Out:
# Holt-Winters
# MAE: 792.5496957996361
# RMSE: 980.1294825731268
# R2: -0.0057699326053277655

# %% [markdown]
# ### Model-5 FB Prophet

# %% [raw]
# Prophet requires only two columns.

# %%
# !pip install prophet
# Out:
# Requirement already satisfied: prophet in C:\Users\javee\anaconda3\Lib\site-packages (1.3.0)
# Requirement already satisfied: cmdstanpy>=1.0.4 in C:\Users\javee\anaconda3\Lib\site-packages (from prophet) (1.3.0)
# Requirement already satisfied: numpy>=1.15.4 in C:\Users\javee\anaconda3\Lib\site-packages (from prophet) (2.4.6)
# Requirement already satisfied: matplotlib>=2.0.0 in C:\Users\javee\anaconda3\Lib\site-packages (from prophet) (3.10.9)
# Requirement already satisfied: pandas>=1.0.4 in C:\Users\javee\anaconda3\Lib\site-packages (from prophet) (3.0.3)
# Requirement already satisfied: holidays<1,>=0.25 in C:\Users\javee\anaconda3\Lib\site-packages (from prophet) (0.99)
# Requirement already satisfied: tqdm>=4.36.1 in C:\Users\javee\anaconda3\Lib\site-packages (from prophet) (4.68.2)
# Requirement already satisfied: importlib_resources in C:\Users\javee\anaconda3\Lib\site-packages (from prophet) (7.1.0)
# Requirement already satisfied: python-dateutil<3,>=2.9.0.post0 in C:\Users\javee\anaconda3\Lib\site-packages (from holidays<1,>=0.25->prophet) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in C:\Users\javee\anaconda3\Lib\site-packages (from python-dateutil<3,>=2.9.0.post0->holidays<1,>=0.25->prophet) (1.17.0)
# Requirement already satisfied: stanio<2.0.0,>=0.4.0 in C:\Users\javee\anaconda3\Lib\site-packages (from cmdstanpy>=1.0.4->prophet) (0.5.1)
# Requirement already satisfied: contourpy>=1.0.1 in C:\Users\javee\anaconda3\Lib\site-packages (from matplotlib>=2.0.0->prophet) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in C:\Users\javee\anaconda3\Lib\site-packages (from matplotlib>=2.0.0->prophet) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in C:\Users\javee\anaconda3\Lib\site-packages (from matplotlib>=2.0.0->prophet) (4.63.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in C:\Users\javee\anaconda3\Lib\site-packages (from matplotlib>=2.0.0->prophet) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in C:\Users\javee\anaconda3\Lib\site-packages (from matplotlib>=2.0.0->prophet) (26.0)
# Requirement already satisfied: pillow>=8 in C:\Users\javee\anaconda3\Lib\site-packages (from matplotlib>=2.0.0->prophet) (12.2.0)
# Requirement already satisfied: pyparsing>=3 in C:\Users\javee\anaconda3\Lib\site-packages (from matplotlib>=2.0.0->prophet) (3.2.5)
# Requirement already satisfied: tzdata in C:\Users\javee\anaconda3\Lib\site-packages (from pandas>=1.0.4->prophet) (2026.2)
# Requirement already satisfied: colorama in C:\Users\javee\anaconda3\Lib\site-packages (from tqdm>=4.36.1->prophet) (0.4.6)

# %%
from prophet import Prophet

# Convert index to column
prophet_df = df[['PJMW_MW']].reset_index()

# Rename columns for Prophet
prophet_df.rename(columns={
    'Datetime': 'ds',
    'PJMW_MW': 'y'
}, inplace=True)

prophet_df.head()
# Out:
#                    ds       y
# 0 2002-05-01 01:00:00  4503.0
# 1 2002-05-01 02:00:00  4418.0
# 2 2002-05-01 03:00:00  4310.0
# 3 2002-05-01 04:00:00  4282.0
# 4 2002-05-01 05:00:00  4431.0

# %% [markdown]
# #### Train-Test-Split

# %%
train_prophet, test_prophet = train_test_split(
    prophet_df,
    test_size=0.2,
    random_state=42
)

# %% [markdown]
# #### Model Build

# %%
prophet_model = Prophet()

prophet_model.fit(train_prophet)
# Out:
# 10:40:22 - cmdstanpy - INFO - Chain [1] start processing
# 10:42:13 - cmdstanpy - INFO - Chain [1] done processing

# %% [markdown]
# #### Prediction

# %%
future = test_prophet[['ds']]

forecast = prophet_model.predict(future)

prophet_pred = forecast['yhat'].values

# %% [markdown]
# #### Evaluation

# %%
prophet_mae = mean_absolute_error(test_prophet['y'], prophet_pred)

prophet_rmse = np.sqrt(mean_squared_error(test_prophet['y'], prophet_pred))

prophet_r2 =  r2_score(test_prophet['y'], prophet_pred)

print("FB-Prophet")
print("MAE:", prophet_mae)
print("RMSE:", prophet_rmse)
print("R2:", prophet_r2)
# Out:
# FB-Prophet
# MAE: 1009.2320351922298
# RMSE: 1252.482726834933
# R2: -0.6423859926566311

# %% [markdown]
# ### Visualization Plots of all Models

# %%
models = {
    "Linear Regression": lr_pred,
    "Random Forest": rf_pred,
    "XGBoost": xgb_pred,
    "Holt-Winters": hw_pred,
    "FB-Prophet": prophet_pred
}

for name, pred in models.items():

    plt.figure(figsize=(15,5))

    plt.plot(y_test.values, label="Actual", linewidth=2)
    plt.plot(pred, label="Predicted", linewidth=2)

    plt.title(f"{name}: Actual vs Predicted")
    plt.xlabel("Time")
    plt.ylabel("Energy Consumption")
    plt.legend()
    plt.grid(True)

    plt.show()

# %% [markdown]
# ### Comparison Table

# %% [raw]
# 1. MAE (Lower is Better)
# 2. RMSE (Lower is Better)
# 3. R² Score (Higher is Better)

# %%
# ==============================
# MODEL COMPARISON
# ==============================

print("\n" + "="*90)
print("FINAL RESULTS - ALL MODELS COMPARISON")
print("="*90)

results = {
    'Model': [
        'Linear Regression',
        'Random Forest',
        'XGBoost',
        'FB Prophet',
        'Holt-Winters'
    ],
    'MAE': [
        lr_mae,
        rf_mae,
        xgb_mae,
        prophet_mae,
        hw_mae
    ],
    'RMSE': [
        lr_rmse,
        rf_rmse,
        xgb_rmse,
        prophet_rmse,
        hw_rmse
    ],
    'R2 Score': [
        lr_r2,
        rf_r2,
        xgb_r2,
        prophet_r2,
        hw_r2
    ]
}

results_df = pd.DataFrame(results)

# Sort by MAE (lower is better)
results_df = results_df.sort_values(by='MAE').reset_index(drop=True)

print("\n")
print(results_df.to_string(index=False))

# ==============================
# BEST MODEL
# ==============================

best_model = results_df.iloc[0]

print("\n" + "="*90)
print(f"🏆 BEST MODEL : {best_model['Model']}")
print(f"   MAE       : {best_model['MAE']:.2f}")
print(f"   RMSE      : {best_model['RMSE']:.2f}")
print(f"   R² Score  : {best_model['R2 Score']:.4f}")
print("="*90)

# ==============================
# MODEL RANKING
# ==============================

print("\nMODEL RANKING:\n")

medals = ['🥇', '🥈', '🥉', '4️⃣', '5️⃣']

for idx, row in results_df.iterrows():
    print(
        f"{medals[idx]} {idx+1}. "
        f"{row['Model']:<20}"
        f"MAE: {row['MAE']:10.2f}   "
        f"RMSE: {row['RMSE']:10.2f}   "
        f"R²: {row['R2 Score']:.4f}"
    )

print("="*90)
# Out:
# ==========================================================================================
# FINAL RESULTS - ALL MODELS COMPARISON
# ==========================================================================================
#
#
#             Model         MAE        RMSE  R2 Score
#           XGBoost  209.602769  276.884900  0.922518
#     Random Forest  235.237713  313.705705  0.900541
# Linear Regression  289.704058  371.358134  0.860625
#      Holt-Winters  792.549696  980.129483 -0.005770
#        FB Prophet 1009.232035 1252.482727 -0.642386
#
# ==========================================================================================
# 🏆 BEST MODEL : XGBoost
#    MAE       : 209.60
#    RMSE      : 276.88
#    R² Score  : 0.9225
# ==========================================================================================
#
# MODEL RANKING:
#
# 🥇 1. XGBoost             MAE:     209.60   RMSE:     276.88   R²: 0.9225
# 🥈 2. Random Forest       MAE:     235.24   RMSE:     313.71   R²: 0.9005
# 🥉 3. Linear Regression   MAE:     289.70   RMSE:     371.36   R²: 0.8606
# 4️⃣ 4. Holt-Winters        MAE:     792.55   RMSE:     980.13   R²: -0.0058
# 5️⃣ 5. FB Prophet          MAE:    1009.23   RMSE:    1252.48   R²: -0.6424
# ==========================================================================================

# %% [markdown]
# ### Forecasting Next 30 days

# %%
future_hours = 24 * 30

# Use the full dataset as history
history = df.copy()

future_predictions = []

for i in range(future_hours):

    # Next timestamp
    next_time = history.index[-1] + pd.Timedelta(hours=1)

    # Calendar features
    hour = next_time.hour
    dayofweek = next_time.dayofweek
    month = next_time.month
    quarter = next_time.quarter
    year = next_time.year
    dayofyear = next_time.dayofyear

    # Lag features
    lag24 = history['PJMW_MW'].iloc[-24]
    lag48 = history['PJMW_MW'].iloc[-48]
    lag168 = history['PJMW_MW'].iloc[-168]

    # Rolling features
    rolling24_mean = history['PJMW_MW'].iloc[-24:].mean()
    rolling168_mean = history['PJMW_MW'].iloc[-168:].mean()
    rolling_30day = history['PJMW_MW'].iloc[-720:].mean()

    future_row = pd.DataFrame({
        'hour': [hour],
        'dayofweek': [dayofweek],
        'month': [month],
        'quarter': [quarter],
        'year': [year],
        'dayofyear': [dayofyear],
        'rolling_30day': [rolling_30day],
        'lag24': [lag24],
        'lag48': [lag48],
        'lag168': [lag168],
        'rolling24_mean': [rolling24_mean],
        'rolling168_mean': [rolling168_mean]
    })

    # Scale using the scaler fitted on the training data
    future_scaled = scaler.transform(future_row)

    # Predict
    pred = xgb_model.predict(future_scaled)[0]

    future_predictions.append(pred)

    # Append prediction for next iteration
    history.loc[next_time] = {
        'PJMW_MW': pred,
        'hour': hour,
        'dayofweek': dayofweek,
        'month': month,
        'quarter': quarter,
        'year': year,
        'dayofyear': dayofyear,
        'rolling_30day': rolling_30day,
        'lag24': lag24,
        'lag48': lag48,
        'lag168': lag168,
        'rolling24_mean': rolling24_mean,
        'rolling168_mean': rolling168_mean
    }

# %% [markdown]
# #### Forecast Dataframe

# %%
forecast_xgb = pd.DataFrame({
    'Datetime': pd.date_range(
        start=df.index[-1] + pd.Timedelta(hours=1),
        periods=future_hours,
        freq='h'
    ),
    'Forecast_MW': future_predictions
})

forecast_xgb.head()
# Out:
#              Datetime  Forecast_MW
# 0 2018-08-03 01:00:00  4925.880859
# 1 2018-08-03 02:00:00  4717.304688
# 2 2018-08-03 03:00:00  4646.020020
# 3 2018-08-03 04:00:00  4555.225586
# 4 2018-08-03 05:00:00  4576.850098

# %% [markdown]
# #### Visualization Plot

# %%
plt.figure(figsize=(16,6))

plt.plot(
    df.index[-24*7:],
    df['PJMW_MW'].tail(24*7),
    label='Historical',
    linewidth=2
)

plt.plot(
    forecast_xgb['Datetime'],
    forecast_xgb['Forecast_MW'],
    color='red',
    linewidth=2,
    label='XGBoost Forecast'
)

plt.title('XGBoost Forecast - Next 30 Days')
plt.xlabel('Date')
plt.ylabel('Power (MW)')
plt.legend()
plt.grid(alpha=0.3)

plt.show()

# %%
import pickle

with open("energy_model.pkl", "wb") as f:
    pickle.dump(xgb_model, f)
